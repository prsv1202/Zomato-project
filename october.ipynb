# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/home/pendlimarri/Downloads/zomato.csv',encoding='latin-1')
data.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
data.describe()
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
data.fillna(method='ffill', inplace=True)

# %%
data.isnull().sum()
# Out:
# url                            0
# address                        0
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# phone                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
#Visualizing the locations as per the order.

# %%
data.corr()
# Out:
#        votes
# votes    1.0

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
sns.scatterplot(data.location,data.online_order)
# Out:
# /home/pendlimarri/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='location', ylabel='online_order'>

# %%
objnames=data.dtypes[data.dtypes=='object'].index
numnames=data.dtypes[data.dtypes!='object'].index

# %%
objnames
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'phone',
#        'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
numnames
# Out:
# Index(['votes'], dtype='object')

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data.location,data.votes)
# Out:
# /home/pendlimarri/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='location', ylabel='votes'>

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data.corr(),annot=True,cmap='rainbow')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)

# %%
offline_order =data.online_order[data.online_order != 'yes']
plt.figure(figsize=(8,8))
plt.plot(data.online_order,offline_order)

# %%
sns.boxplot(data.votes,offline_order)
# Out:
# /home/pendlimarri/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='votes', ylabel='online_order'>

# %%
# Visualize the table booking

# %%
data['conf_table'] =data.book_table[data.book_table != 'No']
data['conf_table']
# Out:
# 0        Yes
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 51712    NaN
# 51713    NaN
# 51714    NaN
# 51715    Yes
# 51716    NaN
# Name: conf_table, Length: 51717, dtype: object

# %%
sns.scatterplot(data.online_order,data.conf_table)
# Out:
# /home/pendlimarri/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='online_order', ylabel='conf_table'>

# %%
sns.boxplot(data.votes,data.conf_table)
# Out:
# /home/pendlimarri/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='votes', ylabel='conf_table'>

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data.online_order,data.location)
# Out:
# /home/pendlimarri/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='online_order', ylabel='location'>

# %%
plt.figure(figsize=(20,10))

sns.scatterplot(data.rate,data.location)
# Out:
# /home/pendlimarri/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='rate', ylabel='location'>

# %%
data.rate.value_counts()
# Out:
# NEW       2956
# 3.7/5     2313
# 3.9/5     2285
# 3.8/5     2212
# 3.6/5     2168
#           ...
# 2.2 /5       8
# 2.0 /5       7
# 2.0/5        4
# 1.8 /5       3
# 1.8/5        2
# Name: rate, Length: 64, dtype: int64

# %%
data.groupby('rate').mean().sort_values('votes',ascending=False)
# Out:
#               votes
# rate
# 4.7 /5  5680.539326
# 4.7/5   5065.000000
# 4.9/5   4419.423077
# 4.9 /5  3597.718750
# 4.8 /5  2959.883721
# ...             ...
# 3.3/5     26.920817
# 3.2 /5    24.791764
# 3.3 /5    22.654358
# -          0.000000
# NEW        0.000000
#
# [64 rows x 1 columns]

# %%
data.groupby('name').mean().sort_values('votes',ascending=False)

# %%
plt.figure(figsize=(8,10))
sns.boxplot(data.votes,data.rate)
# Out:
# /home/pendlimarri/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='votes', ylabel='rate'>

# %%
data.groupby('name').mean().sort_values('votes',ascending=False)
# Out:
#                                                votes
# name
# Byg Brewski Brewing Company             16588.500000
# Toit                                    14956.000000
# The Black Pearl                          9562.333333
# Big Pitcher                              9164.500000
# Arbor Brewing Company                    8396.545455
# ...                                              ...
# Mirchi- The Indian Street Food Kitchen      0.000000
# Mist N Creams                               0.000000
# Mithai Ghar                                 0.000000
# Mitran Da Adda                              0.000000
# sCoolMeal                                   0.000000
#
# [8792 rows x 1 columns]

# %%
pd.pivot_table(data=data,values='votes',index='name',columns='book_table',aggfunc='mean')
# Out:
# book_table                                         No    Yes
# name
# #FeelTheROLL                                    7.000    NaN
# #L-81 Cafe                                     48.000    NaN
# #Vibes Restro                                   0.000    NaN
# #refuel                                        37.000    NaN
# 'Brahmins' Thatte Idli                          0.000    NaN
# ...                                               ...    ...
# late100                                         0.000    NaN
# nu.tree                                       180.375    NaN
# re:cess - Hilton Bangalore Embassy GolfLinks      NaN  146.0
# repEAT Hub                                      0.000    NaN
# sCoolMeal                                       0.000    NaN
#
# [8792 rows x 2 columns]

# %%
#Compare the outliers

# %%
out_vot=data['votes'].quantile([0.25,0.50,0.75,0.975])
out_vot
# Out:
# 0.250       7.0
# 0.500      41.0
# 0.750     198.0
# 0.975    2286.0
# Name: votes, dtype: float64

# %%
#####conclude your dataset
From the EDA process of the zomata.csv dataset i concluded that 'Byg Brewski Brewing Company' is the company whih have highest rating
compare to other companies mentioned in the dataset.
